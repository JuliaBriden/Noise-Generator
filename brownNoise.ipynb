# %%
from acoustics import Signal
import numpy as np
# %matplotlib inline
from IPython.display import Audio
import seaborn as sns # seaborn for prettier graphs

# %%
noise_data = acoustics.generator.noise(44100, color='brown', state=None)

# %%
s = Signal(noise_data, fs=11025)

# %%
Audio(data=s, rate=s.fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
s.power_spectrum()
# Out:
# (array([0.00000e+00, 2.50000e-01, 5.00000e-01, ..., 5.51175e+03,
#         5.51200e+03, 5.51225e+03]),
#  array([4.86230900e-01, 7.59236920e-02, 1.58570322e-01, ...,
#         2.61851819e-10, 5.79483565e-09, 5.51400326e-10]))

# %%
fig = s.plot_power_spectrum()
